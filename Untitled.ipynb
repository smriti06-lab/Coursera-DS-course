# %% [markdown]
# ## __This Notebook will mainly be used for the Captsone Project__

# %% [markdown]
# ### This is Smriti's notebook for the final captson project!

# %%
import pandas as pd

# %%
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
