# %% [markdown]
# # The Battle of Neigbourhoods

# %% [markdown]
# ## This project is to be submitted as the Coursera Capstone assignment

# %% [markdown]
# ### Being interested in business, I have always fascinated the idea of starting my own business with data science techniques. With New York being the most populous city in the states, I hope to find areas to open a restaurant - whether it be sole proprietorship, or just a franchise. Given the fact that restaurants are structed in what is called monopolistic competition in economics, it is very hard to be successful as the products are similar but slightly differentiated. Even though there are almost no barriers to entry, it is very important to consider the location to avoid such competition or it will be hard to have variable costs because there will be a lot more sunk costs.

# %% [markdown]
# ##### Success Criteria: The success criteria of the project will be a good recommendation of borough/Neighborhood choice to XYZ Company Ltd based on Lack of such restaurants in that location and nearest suppliers of ingredients
